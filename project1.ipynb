# %%
import pandas as pd

# %%
df=pd.read_csv('logistics_dataset_uncleaned.csv')

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name           Email  \
# 0        S981356   O13241       C2917     Jane Smith           jane@
# 1        S316311   O56814       C9290     Jane Smith             NaN
# 2        S470009   O66124       C1239     Amit Kumar  amit@gmail.com
# 3        S459529   O28293       C5966  michael brown           jane@
# 4        S372486   O40352       C6710    Fatima Noor             NaN
# ...          ...      ...         ...            ...             ...
# 9995     S331063   O20146       C9393     Amit Kumar  amit@gmail.com
# 9996     S703532   O14424       C5315    Fatima Noor             NaN
# 9997     S684607   O29085       C5106         Li Wei           jane@
# 9998     S145436   O48653       C4340     Amit Kumar             NaN
# 9999     S167942   O97916       C2233       John Doe           jane@
#
#              Phone       City Country Region  Postal_Code  ...    Fuel_Cost  \
# ...

# %%
df.duplicated('Shipment_ID')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
df=df.drop_duplicates('Shipment_ID')

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name           Email  \
# 0        S981356   O13241       C2917     Jane Smith           jane@
# 1        S316311   O56814       C9290     Jane Smith             NaN
# 2        S470009   O66124       C1239     Amit Kumar  amit@gmail.com
# 3        S459529   O28293       C5966  michael brown           jane@
# 4        S372486   O40352       C6710    Fatima Noor             NaN
# ...          ...      ...         ...            ...             ...
# 9995     S331063   O20146       C9393     Amit Kumar  amit@gmail.com
# 9996     S703532   O14424       C5315    Fatima Noor             NaN
# 9997     S684607   O29085       C5106         Li Wei           jane@
# 9998     S145436   O48653       C4340     Amit Kumar             NaN
# 9999     S167942   O97916       C2233       John Doe           jane@
#
#              Phone       City Country Region  Postal_Code  ...    Fuel_Cost  \
# ...

# %%
df.duplicated('Order_ID')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998     True
# 9999    False
# Length: 9948, dtype: bool

# %%
df=df.drop_duplicates('Order_ID')

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name           Email  \
# 0        S981356   O13241       C2917     Jane Smith           jane@
# 1        S316311   O56814       C9290     Jane Smith             NaN
# 2        S470009   O66124       C1239     Amit Kumar  amit@gmail.com
# 3        S459529   O28293       C5966  michael brown           jane@
# 4        S372486   O40352       C6710    Fatima Noor             NaN
# ...          ...      ...         ...            ...             ...
# 9994     S274987   O34297       C3828     Amit Kumar             NaN
# 9995     S331063   O20146       C9393     Amit Kumar  amit@gmail.com
# 9996     S703532   O14424       C5315    Fatima Noor             NaN
# 9997     S684607   O29085       C5106         Li Wei           jane@
# 9999     S167942   O97916       C2233       John Doe           jane@
#
#              Phone       City Country Region  Postal_Code  ...    Fuel_Cost  \
# ...

# %%
df.duplicated(subset=['Customer_ID','Email'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9994    False
# 9995    False
# 9996    False
# 9997     True
# 9999    False
# Length: 9413, dtype: bool

# %%
df=df.drop_duplicates(subset=['Customer_ID','Email'])

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name           Email  \
# 0        S981356   O13241       C2917     Jane Smith           jane@
# 1        S316311   O56814       C9290     Jane Smith             NaN
# 2        S470009   O66124       C1239     Amit Kumar  amit@gmail.com
# 3        S459529   O28293       C5966  michael brown           jane@
# 4        S372486   O40352       C6710    Fatima Noor             NaN
# ...          ...      ...         ...            ...             ...
# 9987     S996729   O86227       C3986  michael brown  amit@gmail.com
# 9994     S274987   O34297       C3828     Amit Kumar             NaN
# 9995     S331063   O20146       C9393     Amit Kumar  amit@gmail.com
# 9996     S703532   O14424       C5315    Fatima Noor             NaN
# 9999     S167942   O97916       C2233       John Doe           jane@
#
#              Phone       City Country Region  Postal_Code  ...    Fuel_Cost  \
# ...

# %%
df["City"].fillna("Unknown",inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\2763263256.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["City"].fillna("Unknown",inplace=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\2763263256.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["City"].fillna("Unknown",inplace=True)

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name           Email  \
# 0        S981356   O13241       C2917     Jane Smith           jane@
# 1        S316311   O56814       C9290     Jane Smith             NaN
# 2        S470009   O66124       C1239     Amit Kumar  amit@gmail.com
# 3        S459529   O28293       C5966  michael brown           jane@
# 4        S372486   O40352       C6710    Fatima Noor             NaN
# ...          ...      ...         ...            ...             ...
# 9987     S996729   O86227       C3986  michael brown  amit@gmail.com
# 9994     S274987   O34297       C3828     Amit Kumar             NaN
# 9995     S331063   O20146       C9393     Amit Kumar  amit@gmail.com
# 9996     S703532   O14424       C5315    Fatima Noor             NaN
# 9999     S167942   O97916       C2233       John Doe           jane@
#
#              Phone       City Country Region  Postal_Code  ...    Fuel_Cost  \
# ...

# %%
df["Country"].fillna("Unknown",inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\982552147.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Country"].fillna("Unknown",inplace=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\982552147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Country"].fillna("Unknown",inplace=True)

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name           Email  \
# 0        S981356   O13241       C2917     Jane Smith           jane@
# 1        S316311   O56814       C9290     Jane Smith             NaN
# 2        S470009   O66124       C1239     Amit Kumar  amit@gmail.com
# 3        S459529   O28293       C5966  michael brown           jane@
# 4        S372486   O40352       C6710    Fatima Noor             NaN
# ...          ...      ...         ...            ...             ...
# 9987     S996729   O86227       C3986  michael brown  amit@gmail.com
# 9994     S274987   O34297       C3828     Amit Kumar             NaN
# 9995     S331063   O20146       C9393     Amit Kumar  amit@gmail.com
# 9996     S703532   O14424       C5315    Fatima Noor             NaN
# 9999     S167942   O97916       C2233       John Doe           jane@
#
#              Phone       City  Country Region  Postal_Code  ...    Fuel_Cost  \
# ...

# %%
df["Category"].fillna("Misc",inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\3439075271.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Category"].fillna("Misc",inplace=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\3439075271.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Category"].fillna("Misc",inplace=True)

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name           Email  \
# 0        S981356   O13241       C2917     Jane Smith           jane@
# 1        S316311   O56814       C9290     Jane Smith             NaN
# 2        S470009   O66124       C1239     Amit Kumar  amit@gmail.com
# 3        S459529   O28293       C5966  michael brown           jane@
# 4        S372486   O40352       C6710    Fatima Noor             NaN
# ...          ...      ...         ...            ...             ...
# 9987     S996729   O86227       C3986  michael brown  amit@gmail.com
# 9994     S274987   O34297       C3828     Amit Kumar             NaN
# 9995     S331063   O20146       C9393     Amit Kumar  amit@gmail.com
# 9996     S703532   O14424       C5315    Fatima Noor             NaN
# 9999     S167942   O97916       C2233       John Doe           jane@
#
#              Phone       City  Country Region  Postal_Code  ...    Fuel_Cost  \
# ...

# %%
x = df["Weight_kg"].mean()
df.fillna({"Weight_kg": x}, inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\3793572486.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.fillna({"Weight_kg": x}, inplace=True)

# %%
x
# Out:
# np.float64(46.370715781593645)

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name           Email  \
# 0        S981356   O13241       C2917     Jane Smith           jane@
# 1        S316311   O56814       C9290     Jane Smith             NaN
# 2        S470009   O66124       C1239     Amit Kumar  amit@gmail.com
# 3        S459529   O28293       C5966  michael brown           jane@
# 4        S372486   O40352       C6710    Fatima Noor             NaN
# ...          ...      ...         ...            ...             ...
# 9987     S996729   O86227       C3986  michael brown  amit@gmail.com
# 9994     S274987   O34297       C3828     Amit Kumar             NaN
# 9995     S331063   O20146       C9393     Amit Kumar  amit@gmail.com
# 9996     S703532   O14424       C5315    Fatima Noor             NaN
# 9999     S167942   O97916       C2233       John Doe           jane@
#
#              Phone       City  Country Region  Postal_Code  ...    Fuel_Cost  \
# ...

# %%
df["Delivery_Mode"].fillna("road",inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\3904423890.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Delivery_Mode"].fillna("road",inplace=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\3904423890.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Delivery_Mode"].fillna("road",inplace=True)

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name           Email  \
# 0        S981356   O13241       C2917     Jane Smith           jane@
# 1        S316311   O56814       C9290     Jane Smith             NaN
# 2        S470009   O66124       C1239     Amit Kumar  amit@gmail.com
# 3        S459529   O28293       C5966  michael brown           jane@
# 4        S372486   O40352       C6710    Fatima Noor             NaN
# ...          ...      ...         ...            ...             ...
# 9987     S996729   O86227       C3986  michael brown  amit@gmail.com
# 9994     S274987   O34297       C3828     Amit Kumar             NaN
# 9995     S331063   O20146       C9393     Amit Kumar  amit@gmail.com
# 9996     S703532   O14424       C5315    Fatima Noor             NaN
# 9999     S167942   O97916       C2233       John Doe           jane@
#
#              Phone       City  Country Region  Postal_Code  ...    Fuel_Cost  \
# ...

# %%
df["Fuel_Cost"].fillna(df.groupby("Transport_Type")["Fuel_Cost"].transform("median"),inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\988851821.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Fuel_Cost"].fillna(df.groupby("Transport_Type")["Fuel_Cost"].transform("median"),inplace=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\988851821.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name           Email  \
# 0        S981356   O13241       C2917     Jane Smith           jane@
# 1        S316311   O56814       C9290     Jane Smith             NaN
# 2        S470009   O66124       C1239     Amit Kumar  amit@gmail.com
# 3        S459529   O28293       C5966  michael brown           jane@
# 4        S372486   O40352       C6710    Fatima Noor             NaN
# ...          ...      ...         ...            ...             ...
# 9987     S996729   O86227       C3986  michael brown  amit@gmail.com
# 9994     S274987   O34297       C3828     Amit Kumar             NaN
# 9995     S331063   O20146       C9393     Amit Kumar  amit@gmail.com
# 9996     S703532   O14424       C5315    Fatima Noor             NaN
# 9999     S167942   O97916       C2233       John Doe           jane@
#
#              Phone       City  Country Region  Postal_Code  ...    Fuel_Cost  \
# ...

# %%
df["Remarks"].fillna("No Remarks",inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\3973173657.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Remarks"].fillna("No Remarks",inplace=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\3973173657.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Remarks"].fillna("No Remarks",inplace=True)

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name           Email  \
# 0        S981356   O13241       C2917     Jane Smith           jane@
# 1        S316311   O56814       C9290     Jane Smith             NaN
# 2        S470009   O66124       C1239     Amit Kumar  amit@gmail.com
# 3        S459529   O28293       C5966  michael brown           jane@
# 4        S372486   O40352       C6710    Fatima Noor             NaN
# ...          ...      ...         ...            ...             ...
# 9987     S996729   O86227       C3986  michael brown  amit@gmail.com
# 9994     S274987   O34297       C3828     Amit Kumar             NaN
# 9995     S331063   O20146       C9393     Amit Kumar  amit@gmail.com
# 9996     S703532   O14424       C5315    Fatima Noor             NaN
# 9999     S167942   O97916       C2233       John Doe           jane@
#
#              Phone       City  Country Region  Postal_Code  ...    Fuel_Cost  \
# ...

# %%
df = df[df["Quantity"]>0]

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name           Email  \
# 0        S981356   O13241       C2917     Jane Smith           jane@
# 1        S316311   O56814       C9290     Jane Smith             NaN
# 2        S470009   O66124       C1239     Amit Kumar  amit@gmail.com
# 3        S459529   O28293       C5966  michael brown           jane@
# 4        S372486   O40352       C6710    Fatima Noor             NaN
# ...          ...      ...         ...            ...             ...
# 9987     S996729   O86227       C3986  michael brown  amit@gmail.com
# 9994     S274987   O34297       C3828     Amit Kumar             NaN
# 9995     S331063   O20146       C9393     Amit Kumar  amit@gmail.com
# 9996     S703532   O14424       C5315    Fatima Noor             NaN
# 9999     S167942   O97916       C2233       John Doe           jane@
#
#              Phone       City  Country Region  Postal_Code  ...    Fuel_Cost  \
# ...

# %%
df = df[df["Weight_kg"]>0]

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name           Email  \
# 0        S981356   O13241       C2917     Jane Smith           jane@
# 1        S316311   O56814       C9290     Jane Smith             NaN
# 2        S470009   O66124       C1239     Amit Kumar  amit@gmail.com
# 3        S459529   O28293       C5966  michael brown           jane@
# 4        S372486   O40352       C6710    Fatima Noor             NaN
# ...          ...      ...         ...            ...             ...
# 9987     S996729   O86227       C3986  michael brown  amit@gmail.com
# 9994     S274987   O34297       C3828     Amit Kumar             NaN
# 9995     S331063   O20146       C9393     Amit Kumar  amit@gmail.com
# 9996     S703532   O14424       C5315    Fatima Noor             NaN
# 9999     S167942   O97916       C2233       John Doe           jane@
#
#              Phone       City  Country Region  Postal_Code  ...    Fuel_Cost  \
# ...

# %%
df=df[df['Total_Price']>0]

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name           Email  \
# 0        S981356   O13241       C2917     Jane Smith           jane@
# 1        S316311   O56814       C9290     Jane Smith             NaN
# 2        S470009   O66124       C1239     Amit Kumar  amit@gmail.com
# 3        S459529   O28293       C5966  michael brown           jane@
# 4        S372486   O40352       C6710    Fatima Noor             NaN
# ...          ...      ...         ...            ...             ...
# 9987     S996729   O86227       C3986  michael brown  amit@gmail.com
# 9994     S274987   O34297       C3828     Amit Kumar             NaN
# 9995     S331063   O20146       C9393     Amit Kumar  amit@gmail.com
# 9996     S703532   O14424       C5315    Fatima Noor             NaN
# 9999     S167942   O97916       C2233       John Doe           jane@
#
#              Phone       City  Country Region  Postal_Code  ...    Fuel_Cost  \
# ...

# %%
df = df[df["Delivery_Date"] >= df["Shipment_Date"]]

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name             Email  \
# 4        S372486   O40352       C6710    Fatima Noor               NaN
# 7        S734726   O77929       C3183  michael brown    amit@gmail.com
# 8        S728975   O40008       C3098     Jane Smith    amit@gmail.com
# 9        S427342   O36381       C5569       John Doe  john@example.com
# 12       S451621   O15692       C4872    Fatima Noor             jane@
# ...          ...      ...         ...            ...               ...
# 9986     S663859   O33660       C6920     Jane Smith  john@example.com
# 9987     S996729   O86227       C3986  michael brown    amit@gmail.com
# 9994     S274987   O34297       C3828     Amit Kumar               NaN
# 9995     S331063   O20146       C9393     Amit Kumar    amit@gmail.com
# 9996     S703532   O14424       C5315    Fatima Noor               NaN
#
#              Phone       City  Country Region  Postal_Code  ...    Fuel_Cost  \
# ...

# %%
df=df[df['Delay_Days']>=-1]

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name             Email  \
# 4        S372486   O40352       C6710    Fatima Noor               NaN
# 7        S734726   O77929       C3183  michael brown    amit@gmail.com
# 8        S728975   O40008       C3098     Jane Smith    amit@gmail.com
# 9        S427342   O36381       C5569       John Doe  john@example.com
# 15       S639574   O65339       C2260       John Doe             jane@
# ...          ...      ...         ...            ...               ...
# 9986     S663859   O33660       C6920     Jane Smith  john@example.com
# 9987     S996729   O86227       C3986  michael brown    amit@gmail.com
# 9994     S274987   O34297       C3828     Amit Kumar               NaN
# 9995     S331063   O20146       C9393     Amit Kumar    amit@gmail.com
# 9996     S703532   O14424       C5315    Fatima Noor               NaN
#
#              Phone       City  Country Region  Postal_Code  ...    Fuel_Cost  \
# ...

# %%
df["Payment_Mode"]=df["Payment_Mode"].replace({"Credt":"Credit","Debet":"Debit"})
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\2191643360.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Payment_Mode"]=df["Payment_Mode"].replace({"Credt":"Credit","Debet":"Debit"})

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name             Email  \
# 4        S372486   O40352       C6710    Fatima Noor               NaN
# 7        S734726   O77929       C3183  michael brown    amit@gmail.com
# 8        S728975   O40008       C3098     Jane Smith    amit@gmail.com
# 9        S427342   O36381       C5569       John Doe  john@example.com
# 15       S639574   O65339       C2260       John Doe             jane@
# ...          ...      ...         ...            ...               ...
# 9986     S663859   O33660       C6920     Jane Smith  john@example.com
# 9987     S996729   O86227       C3986  michael brown    amit@gmail.com
# 9994     S274987   O34297       C3828     Amit Kumar               NaN
# 9995     S331063   O20146       C9393     Amit Kumar    amit@gmail.com
# 9996     S703532   O14424       C5315    Fatima Noor               NaN
#
#              Phone       City  Country Region  Postal_Code  ...    Fuel_Cost  \
# ...

# %%
df["Status"]=df["Status"].replace({"delayed":"Delayed","DELAYED":"Delayed"})
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\973456718.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Status"]=df["Status"].replace({"delayed":"Delayed","DELAYED":"Delayed"})

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name             Email  \
# 4        S372486   O40352       C6710    Fatima Noor               NaN
# 7        S734726   O77929       C3183  michael brown    amit@gmail.com
# 8        S728975   O40008       C3098     Jane Smith    amit@gmail.com
# 9        S427342   O36381       C5569       John Doe  john@example.com
# 15       S639574   O65339       C2260       John Doe             jane@
# ...          ...      ...         ...            ...               ...
# 9986     S663859   O33660       C6920     Jane Smith  john@example.com
# 9987     S996729   O86227       C3986  michael brown    amit@gmail.com
# 9994     S274987   O34297       C3828     Amit Kumar               NaN
# 9995     S331063   O20146       C9393     Amit Kumar    amit@gmail.com
# 9996     S703532   O14424       C5315    Fatima Noor               NaN
#
#              Phone       City  Country Region  Postal_Code  ...    Fuel_Cost  \
# ...

# %%
df["Country"]=df["Country"].replace({"us":"USA","U.K.":"UK"})
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\2560690752.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Country"]=df["Country"].replace({"us":"USA","U.K.":"UK"})

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name             Email  \
# 4        S372486   O40352       C6710    Fatima Noor               NaN
# 7        S734726   O77929       C3183  michael brown    amit@gmail.com
# 8        S728975   O40008       C3098     Jane Smith    amit@gmail.com
# 9        S427342   O36381       C5569       John Doe  john@example.com
# 15       S639574   O65339       C2260       John Doe             jane@
# ...          ...      ...         ...            ...               ...
# 9986     S663859   O33660       C6920     Jane Smith  john@example.com
# 9987     S996729   O86227       C3986  michael brown    amit@gmail.com
# 9994     S274987   O34297       C3828     Amit Kumar               NaN
# 9995     S331063   O20146       C9393     Amit Kumar    amit@gmail.com
# 9996     S703532   O14424       C5315    Fatima Noor               NaN
#
#              Phone       City  Country Region  Postal_Code  ...    Fuel_Cost  \
# ...

# %%
df=df[df["Email"].str.contains("@", na=False)]

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name             Email  \
# 7        S734726   O77929       C3183  michael brown    amit@gmail.com
# 8        S728975   O40008       C3098     Jane Smith    amit@gmail.com
# 9        S427342   O36381       C5569       John Doe  john@example.com
# 15       S639574   O65339       C2260       John Doe             jane@
# 16       S694897   O55928       C7775  michael brown             jane@
# ...          ...      ...         ...            ...               ...
# 9977     S913811   O78710       C6685    Fatima Noor    amit@gmail.com
# 9980     S424262   O34605       C1678       John Doe    amit@gmail.com
# 9986     S663859   O33660       C6920     Jane Smith  john@example.com
# 9987     S996729   O86227       C3986  michael brown    amit@gmail.com
# 9995     S331063   O20146       C9393     Amit Kumar    amit@gmail.com
#
#              Phone       City  Country Region  Postal_Code  ...    Fuel_Cost  \
# ...

# %%
df=df[df["Distance_km"]<=2000]

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name             Email  \
# 7        S734726   O77929       C3183  michael brown    amit@gmail.com
# 8        S728975   O40008       C3098     Jane Smith    amit@gmail.com
# 9        S427342   O36381       C5569       John Doe  john@example.com
# 15       S639574   O65339       C2260       John Doe             jane@
# 16       S694897   O55928       C7775  michael brown             jane@
# ...          ...      ...         ...            ...               ...
# 9977     S913811   O78710       C6685    Fatima Noor    amit@gmail.com
# 9980     S424262   O34605       C1678       John Doe    amit@gmail.com
# 9986     S663859   O33660       C6920     Jane Smith  john@example.com
# 9987     S996729   O86227       C3986  michael brown    amit@gmail.com
# 9995     S331063   O20146       C9393     Amit Kumar    amit@gmail.com
#
#              Phone       City  Country Region  Postal_Code  ...    Fuel_Cost  \
# ...

# %%
df[df["Delay_Days"]>5]
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name             Email  \
# 8        S728975   O40008       C3098     Jane Smith    amit@gmail.com
# 9        S427342   O36381       C5569       John Doe  john@example.com
# 15       S639574   O65339       C2260       John Doe             jane@
# 16       S694897   O55928       C7775  michael brown             jane@
# 17       S789076   O58826       C3367         Li Wei    amit@gmail.com
# ...          ...      ...         ...            ...               ...
# 9951     S661479   O83798       C7758  michael brown  john@example.com
# 9957     S538834   O66101       C7612     Amit Kumar    amit@gmail.com
# 9980     S424262   O34605       C1678       John Doe    amit@gmail.com
# 9987     S996729   O86227       C3986  michael brown    amit@gmail.com
# 9995     S331063   O20146       C9393     Amit Kumar    amit@gmail.com
#
#              Phone     City  Country Region  Postal_Code  ...    Fuel_Cost  \
# ...

# %%
df[df["Order_Priority"]=="High"]
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name             Email  \
# 7        S734726   O77929       C3183  michael brown    amit@gmail.com
# 8        S728975   O40008       C3098     Jane Smith    amit@gmail.com
# 31       S794002   O70026       C8875         Li Wei  john@example.com
# 48       S196122   O90267       C7159            NaN    amit@gmail.com
# 53       S348688   O42617       C3793  michael brown    amit@gmail.com
# ...          ...      ...         ...            ...               ...
# 9892     S568969   O72984       C6794       John Doe  john@example.com
# 9899     S224168   O96198       C2060     Amit Kumar             jane@
# 9947     S806319   O85510       C3241     Jane Smith  john@example.com
# 9986     S663859   O33660       C6920     Jane Smith  john@example.com
# 9995     S331063   O20146       C9393     Amit Kumar    amit@gmail.com
#
#              Phone       City  Country Region  Postal_Code  ...    Fuel_Cost  \
# ...

# %%
df[df["Delivery_Mode"]=="Air"]
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name             Email  \
# 17       S789076   O58826       C3367         Li Wei    amit@gmail.com
# 25       S777803   O75666       C9408            NaN             jane@
# 40       S478286   O88231       C3295            NaN    amit@gmail.com
# 50       S275615   O56142       C4762     Jane Smith             jane@
# 67       S440122   O85883       C2314  michael brown             jane@
# ...          ...      ...         ...            ...               ...
# 9912     S657504   O31803       C8772         Li Wei    amit@gmail.com
# 9913     S578942   O41717       C1962            NaN             jane@
# 9951     S661479   O83798       C7758  michael brown  john@example.com
# 9956     S551574   O80763       C9492            NaN  john@example.com
# 9965     S496316   O60913       C2565     Amit Kumar    amit@gmail.com
#
#              Phone       City  Country Region  Postal_Code  ...    Fuel_Cost  \
# ...

# %%
df[df["Fuel_Cost"]>8000]
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name             Email  \
# 8        S728975   O40008       C3098     Jane Smith    amit@gmail.com
# 16       S694897   O55928       C7775  michael brown             jane@
# 22       S476484   O24048       C7410            NaN    amit@gmail.com
# 24       S976996   O72852       C9298         Li Wei    amit@gmail.com
# 25       S777803   O75666       C9408            NaN             jane@
# ...          ...      ...         ...            ...               ...
# 9911     S900704   O28416       C5210    Fatima Noor  john@example.com
# 9956     S551574   O80763       C9492            NaN  john@example.com
# 9957     S538834   O66101       C7612     Amit Kumar    amit@gmail.com
# 9965     S496316   O60913       C2565     Amit Kumar    amit@gmail.com
# 9972     S270082   O35307       C8275     Amit Kumar    amit@gmail.com
#
#              Phone     City  Country Region  Postal_Code  ...    Fuel_Cost  \
# ...

# %%
df[df["Total_Price"]>100000]
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name             Email  \
# 16       S694897   O55928       C7775  michael brown             jane@
# 22       S476484   O24048       C7410            NaN    amit@gmail.com
# 24       S976996   O72852       C9298         Li Wei    amit@gmail.com
# 31       S794002   O70026       C8875         Li Wei  john@example.com
# 33       S617814   O77010       C1177       John Doe    amit@gmail.com
# ...          ...      ...         ...            ...               ...
# 9940     S965290   O87888       C9523       John Doe             jane@
# 9972     S270082   O35307       C8275     Amit Kumar    amit@gmail.com
# 9980     S424262   O34605       C1678       John Doe    amit@gmail.com
# 9986     S663859   O33660       C6920     Jane Smith  john@example.com
# 9987     S996729   O86227       C3986  michael brown    amit@gmail.com
#
#              Phone       City  Country Region  Postal_Code  ...    Fuel_Cost  \
# ...

# %%
df[df["Status"]=="Delayed"]
# Out:
#      Shipment_ID Order_ID Customer_ID Customer_Name             Email  \
# 9        S427342   O36381       C5569      John Doe  john@example.com
# 15       S639574   O65339       C2260      John Doe             jane@
# 26       S687190   O54768       C1407    Amit Kumar  john@example.com
# 31       S794002   O70026       C8875        Li Wei  john@example.com
# 49       S813801   O57535       C8550           NaN             jane@
# ...          ...      ...         ...           ...               ...
# 9907     S675484   O62797       C7081        Li Wei  john@example.com
# 9910     S389541   O53676       C2031      John Doe    amit@gmail.com
# 9911     S900704   O28416       C5210   Fatima Noor  john@example.com
# 9913     S578942   O41717       C1962           NaN             jane@
# 9947     S806319   O85510       C3241    Jane Smith  john@example.com
#
#              Phone       City  Country Region  Postal_Code  ...    Fuel_Cost  \
# ...

# %%
df[(df["Country"]=="India") & (df["Total_Price"]>50000)]
# Out:
#      Shipment_ID Order_ID Customer_ID Customer_Name             Email  \
# 9        S427342   O36381       C5569      John Doe  john@example.com
# 33       S617814   O77010       C1177      John Doe    amit@gmail.com
# 47       S308976   O16003       C2855   Fatima Noor  john@example.com
# 49       S813801   O57535       C8550           NaN             jane@
# 91       S440194   O11390       C1349        Li Wei    amit@gmail.com
# ...          ...      ...         ...           ...               ...
# 9779     S228703   O79991       C8381           NaN             jane@
# 9844     S737563   O25479       C2975      John Doe             jane@
# 9882     S543673   O47797       C5770           NaN    amit@gmail.com
# 9907     S675484   O62797       C7081        Li Wei  john@example.com
# 9980     S424262   O34605       C1678      John Doe    amit@gmail.com
#
#              Phone       City Country Region  Postal_Code  ...    Fuel_Cost  \
# ...

# %%
df[df["Insurance"]=="Yes"]
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name             Email  \
# 8        S728975   O40008       C3098     Jane Smith    amit@gmail.com
# 9        S427342   O36381       C5569       John Doe  john@example.com
# 17       S789076   O58826       C3367         Li Wei    amit@gmail.com
# 20       S618003   O67221       C2313  michael brown    amit@gmail.com
# 31       S794002   O70026       C8875         Li Wei  john@example.com
# ...          ...      ...         ...            ...               ...
# 9913     S578942   O41717       C1962            NaN             jane@
# 9940     S965290   O87888       C9523       John Doe             jane@
# 9972     S270082   O35307       C8275     Amit Kumar    amit@gmail.com
# 9977     S913811   O78710       C6685    Fatima Noor    amit@gmail.com
# 9986     S663859   O33660       C6920     Jane Smith  john@example.com
#
#              Phone       City  Country Region  Postal_Code  ...    Fuel_Cost  \
# ...

# %%
df[(df["Category"]=="Electronics")&(df["Delivery_Mode"]=="Air")]
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name             Email  \
# 137      S362430   O85256       C2062     Amit Kumar    amit@gmail.com
# 643      S689694   O23014       C9104     Jane Smith             jane@
# 720      S321694   O85059       C8400       John Doe             jane@
# 738      S562265   O38745       C7853    Fatima Noor             jane@
# 795      S101854   O48106       C1226       John Doe  john@example.com
# ...          ...      ...         ...            ...               ...
# 9013     S593270   O36847       C6689       John Doe  john@example.com
# 9397     S859756   O43762       C2196            NaN    amit@gmail.com
# 9440     S115450   O33980       C7428       John Doe             jane@
# 9524     S910337   O12242       C9827            NaN  john@example.com
# 9951     S661479   O83798       C7758  michael brown  john@example.com
#
#              Phone       City  Country Region  Postal_Code  ...    Fuel_Cost  \
# ...

# %%
df[df["Return_Status"]=="Returned"]
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name             Email  \
# 15       S639574   O65339       C2260       John Doe             jane@
# 48       S196122   O90267       C7159            NaN    amit@gmail.com
# 53       S348688   O42617       C3793  michael brown    amit@gmail.com
# 75       S500169   O57638       C6761       John Doe             jane@
# 79       S665933   O95206       C9026    Fatima Noor  john@example.com
# ...          ...      ...         ...            ...               ...
# 9947     S806319   O85510       C3241     Jane Smith  john@example.com
# 9965     S496316   O60913       C2565     Amit Kumar    amit@gmail.com
# 9977     S913811   O78710       C6685    Fatima Noor    amit@gmail.com
# 9980     S424262   O34605       C1678       John Doe    amit@gmail.com
# 9987     S996729   O86227       C3986  michael brown    amit@gmail.com
#
#              Phone       City  Country Region  Postal_Code  ...    Fuel_Cost  \
# ...

# %%
total_value_per_customer=(df.groupby("Customer_ID")["Total_Price"].sum().reset_index(name="Total_Value"))

# %%
total_value_per_customer
# Out:
#      Customer_ID    Total_Value
# 0          C1015   79017.036226
# 1          C1017   14882.343105
# 2          C1021   50746.420565
# 3          C1037   38876.644400
# 4          C1070  183930.737201
# ...          ...            ...
# 2097       C9985   65423.890909
# 2098       C9988   61620.033408
# 2099       C9991  171978.991210
# 2100       C9993   92774.504026
# 2101       C9996   78649.693299
#
# [2102 rows x 2 columns]

# %%
avg_fuel_cost = (df.groupby("Delivery_Mode")["Fuel_Cost"].mean().reset_index(name="Avg_Fuel_Cost"))

# %%
avg_fuel_cost
# Out:
#   Delivery_Mode  Avg_Fuel_Cost
# 0           Air    5158.462025
# 1          Rail    5364.161772
# 2          Road    5215.581111
# 3          Ship    5334.423854
# 4          road    5368.094002

# %%
customers_multi_country = (df.groupby("Customer_ID")["Country"].nunique().reset_index(name="Country_Count").
    query("Country_Count > 1"))

# %%
customers_multi_country
# Out:
#      Customer_ID  Country_Count
# 24         C1186              2
# 34         C1217              2
# 51         C1275              2
# 83         C1376              2
# 91         C1397              2
# ...          ...            ...
# 2007       C9573              2
# 2031       C9678              2
# 2038       C9704              2
# 2063       C9818              2
# 2082       C9907              2
#
# [157 rows x 2 columns]

# %%
vehicles_over_50 = (df.groupby("Vehicle_ID").size()
      .reset_index(name="shipment_count")
      .query("shipment_count > 5"))

# %%
vehicles_over_50
# Out:
#     Vehicle_ID  shipment_count
# 12        V112               6
# 35        V137               6
# 48        V151               6
# 53        V157               6
# 75        V180               6
# 77        V183               7
# 79        V185               7
# 97        V204               6
# 101       V208               8
# 106       V215               6
# 126       V235               7
# 142       V254               7
# 152       V264               6
# 156       V268               7
# 175       V287               6
# 192       V307               7
# 216       V331               6
# 274       V392               7
# 283       V402               7
# 284       V403               9
# 305       V426               6
# 349       V477               7
# 355       V483               6
# 360       V488               8
# 390       V521               7
# 406       V539               7
# 426       V559               6
# 467       V602               6
# 509       V646               7
# ...

# %%
warehouses_multi_region = (
    df.groupby("Warehouse_Name")["Region"]
      .nunique()
      .reset_index(name="region_count")
      .query("region_count > 1"))

# %%
warehouses_multi_region
# Out:
#   Warehouse_Name  region_count
# 0        Central             4
# 1      North Hub             4
# 2      South Hub             4

# %%
df["Revenue"]=df["Quantity"]*df["Unit_Price"]
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\2034081316.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Revenue"]=df["Quantity"]*df["Unit_Price"]

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name             Email  \
# 7        S734726   O77929       C3183  michael brown    amit@gmail.com
# 8        S728975   O40008       C3098     Jane Smith    amit@gmail.com
# 9        S427342   O36381       C5569       John Doe  john@example.com
# 15       S639574   O65339       C2260       John Doe             jane@
# 16       S694897   O55928       C7775  michael brown             jane@
# ...          ...      ...         ...            ...               ...
# 9977     S913811   O78710       C6685    Fatima Noor    amit@gmail.com
# 9980     S424262   O34605       C1678       John Doe    amit@gmail.com
# 9986     S663859   O33660       C6920     Jane Smith  john@example.com
# 9987     S996729   O86227       C3986  michael brown    amit@gmail.com
# 9995     S331063   O20146       C9393     Amit Kumar    amit@gmail.com
#
#              Phone       City  Country Region  Postal_Code  ...  Distance_km  \
# ...

# %%
df['Delivery_Date'] = pd.to_datetime(df['Delivery_Date'])
df['Shipment_Date'] = pd.to_datetime(df['Shipment_Date'])
df['Delivery_Duration'] = df['Delivery_Date'] - df['Shipment_Date']
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\3608170239.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Delivery_Date'] = pd.to_datetime(df['Delivery_Date'])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\3608170239.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Shipment_Date'] = pd.to_datetime(df['Shipment_Date'])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\3608170239.py:3: SettingWithCopyWarning:
# ...

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name             Email  \
# 7        S734726   O77929       C3183  michael brown    amit@gmail.com
# 8        S728975   O40008       C3098     Jane Smith    amit@gmail.com
# 9        S427342   O36381       C5569       John Doe  john@example.com
# 15       S639574   O65339       C2260       John Doe             jane@
# 16       S694897   O55928       C7775  michael brown             jane@
# ...          ...      ...         ...            ...               ...
# 9977     S913811   O78710       C6685    Fatima Noor    amit@gmail.com
# 9980     S424262   O34605       C1678       John Doe    amit@gmail.com
# 9986     S663859   O33660       C6920     Jane Smith  john@example.com
# 9987     S996729   O86227       C3986  michael brown    amit@gmail.com
# 9995     S331063   O20146       C9393     Amit Kumar    amit@gmail.com
#
#              Phone       City  Country Region  Postal_Code  ...  \
# ...

# %%
df["Fuel_Efficiency"] = df["Distance_km"] / df["Fuel_Cost"]
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\2959251268.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Fuel_Efficiency"] = df["Distance_km"] / df["Fuel_Cost"]

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name             Email  \
# 7        S734726   O77929       C3183  michael brown    amit@gmail.com
# 8        S728975   O40008       C3098     Jane Smith    amit@gmail.com
# 9        S427342   O36381       C5569       John Doe  john@example.com
# 15       S639574   O65339       C2260       John Doe             jane@
# 16       S694897   O55928       C7775  michael brown             jane@
# ...          ...      ...         ...            ...               ...
# 9977     S913811   O78710       C6685    Fatima Noor    amit@gmail.com
# 9980     S424262   O34605       C1678       John Doe    amit@gmail.com
# 9986     S663859   O33660       C6920     Jane Smith  john@example.com
# 9987     S996729   O86227       C3986  michael brown    amit@gmail.com
# 9995     S331063   O20146       C9393     Amit Kumar    amit@gmail.com
#
#              Phone       City  Country Region  Postal_Code  ...  \
# ...

# %%
df["Profit"] = df["Total_Price"] - df["Fuel_Cost"]
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\2741325043.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Profit"] = df["Total_Price"] - df["Fuel_Cost"]

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name             Email  \
# 7        S734726   O77929       C3183  michael brown    amit@gmail.com
# 8        S728975   O40008       C3098     Jane Smith    amit@gmail.com
# 9        S427342   O36381       C5569       John Doe  john@example.com
# 15       S639574   O65339       C2260       John Doe             jane@
# 16       S694897   O55928       C7775  michael brown             jane@
# ...          ...      ...         ...            ...               ...
# 9977     S913811   O78710       C6685    Fatima Noor    amit@gmail.com
# 9980     S424262   O34605       C1678       John Doe    amit@gmail.com
# 9986     S663859   O33660       C6920     Jane Smith  john@example.com
# 9987     S996729   O86227       C3986  michael brown    amit@gmail.com
# 9995     S331063   O20146       C9393     Amit Kumar    amit@gmail.com
#
#              Phone       City  Country Region  Postal_Code  ... Manager_Name  \
# ...

# %%
df["Delay_Flag"] = df["Delay_Days"].apply(lambda x: "Yes" if x > 0 else "No")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\2808876476.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Delay_Flag"] = df["Delay_Days"].apply(lambda x: "Yes" if x > 0 else "No")

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name             Email  \
# 7        S734726   O77929       C3183  michael brown    amit@gmail.com
# 8        S728975   O40008       C3098     Jane Smith    amit@gmail.com
# 9        S427342   O36381       C5569       John Doe  john@example.com
# 15       S639574   O65339       C2260       John Doe             jane@
# 16       S694897   O55928       C7775  michael brown             jane@
# ...          ...      ...         ...            ...               ...
# 9977     S913811   O78710       C6685    Fatima Noor    amit@gmail.com
# 9980     S424262   O34605       C1678       John Doe    amit@gmail.com
# 9986     S663859   O33660       C6920     Jane Smith  john@example.com
# 9987     S996729   O86227       C3986  michael brown    amit@gmail.com
# 9995     S331063   O20146       C9393     Amit Kumar    amit@gmail.com
#
#              Phone       City  Country Region  Postal_Code  ...  \
# ...

# %%
df["Urgency_Level"] = df["Order_Priority"].map({"High": "Urgent","Medium": "Normal","Low": "Low"})
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\930627487.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Urgency_Level"] = df["Order_Priority"].map({"High": "Urgent","Medium": "Normal","Low": "Low"})

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name             Email  \
# 7        S734726   O77929       C3183  michael brown    amit@gmail.com
# 8        S728975   O40008       C3098     Jane Smith    amit@gmail.com
# 9        S427342   O36381       C5569       John Doe  john@example.com
# 15       S639574   O65339       C2260       John Doe             jane@
# 16       S694897   O55928       C7775  michael brown             jane@
# ...          ...      ...         ...            ...               ...
# 9977     S913811   O78710       C6685    Fatima Noor    amit@gmail.com
# 9980     S424262   O34605       C1678       John Doe    amit@gmail.com
# 9986     S663859   O33660       C6920     Jane Smith  john@example.com
# 9987     S996729   O86227       C3986  michael brown    amit@gmail.com
# 9995     S331063   O20146       C9393     Amit Kumar    amit@gmail.com
#
#              Phone       City  Country Region  Postal_Code  ... Payment_Mode  \
# ...

# %%
payment_map = {
    "Cash": 1,
    "Credit": 2,
    "Debit": 3,
    "UPI": 4,
    "Online": 5,
    "Card": 6}
df["Payment_Mode_Encoded"] = df["Payment_Mode"].map(payment_map)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\1962486592.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Payment_Mode_Encoded"] = df["Payment_Mode"].map(payment_map)

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name             Email  \
# 7        S734726   O77929       C3183  michael brown    amit@gmail.com
# 8        S728975   O40008       C3098     Jane Smith    amit@gmail.com
# 9        S427342   O36381       C5569       John Doe  john@example.com
# 15       S639574   O65339       C2260       John Doe             jane@
# 16       S694897   O55928       C7775  michael brown             jane@
# ...          ...      ...         ...            ...               ...
# 9977     S913811   O78710       C6685    Fatima Noor    amit@gmail.com
# 9980     S424262   O34605       C1678       John Doe    amit@gmail.com
# 9986     S663859   O33660       C6920     Jane Smith  john@example.com
# 9987     S996729   O86227       C3986  michael brown    amit@gmail.com
# 9995     S331063   O20146       C9393     Amit Kumar    amit@gmail.com
#
#              Phone       City  Country Region  Postal_Code  ... Insurance  \
# ...

# %%
df["Order_Priority_Encoded"] = df["Order_Priority"].map({"High": 3,"Medium": 2,"Low": 1})
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\3000936895.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Order_Priority_Encoded"] = df["Order_Priority"].map({"High": 3,"Medium": 2,"Low": 1})

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name             Email  \
# 7        S734726   O77929       C3183  michael brown    amit@gmail.com
# 8        S728975   O40008       C3098     Jane Smith    amit@gmail.com
# 9        S427342   O36381       C5569       John Doe  john@example.com
# 15       S639574   O65339       C2260       John Doe             jane@
# 16       S694897   O55928       C7775  michael brown             jane@
# ...          ...      ...         ...            ...               ...
# 9977     S913811   O78710       C6685    Fatima Noor    amit@gmail.com
# 9980     S424262   O34605       C1678       John Doe    amit@gmail.com
# 9986     S663859   O33660       C6920     Jane Smith  john@example.com
# 9987     S996729   O86227       C3986  michael brown    amit@gmail.com
# 9995     S331063   O20146       C9393     Amit Kumar    amit@gmail.com
#
#              Phone       City  Country Region  Postal_Code  ... Return_Status  \
# ...

# %%
top_10_customers = (
    df.groupby("Customer_Name", as_index=False)["Revenue"]
      .sum()
      .sort_values(by="Revenue", ascending=False)
      .head(10))

# %%
top_10_customers
# Out:
#    Customer_Name       Revenue
# 3       John Doe  9.143028e+06
# 2     Jane Smith  8.646884e+06
# 5  michael brown  8.627361e+06
# 1    Fatima Noor  8.217262e+06
# 0     Amit Kumar  7.824763e+06
# 4         Li Wei  7.259645e+06

# %%
top_10_cities = (
    df.groupby("City")
      .size()
      .reset_index(name="Number_of_Shipments")
      .sort_values(by="Number_of_Shipments", ascending=False)
      .head(10))

# %%
top_10_cities
# Out:
#         City  Number_of_Shipments
# 4    Unknown                  402
# 0  Bangalore                  395
# 1    Chennai                  390
# 3     Mumbai                  384
# 2      Delhi                  379
# 5     mumbai                  367

# %%
most_used_delivery_mode = (
    df["Delivery_Mode"]
      .value_counts().head(1))

# %%
most_used_delivery_mode
# Out:
# Delivery_Mode
# Rail    478
# Name: count, dtype: int64

# %%
df["Delivery_Mode"].mode()[0]
# Out:
# 'Rail'

# %%
avg_delay_by_category = (
    df.groupby("Category", as_index=False)["Delay_Days"]
      .mean()
      .rename(columns={"Delay_Days": "Avg_Delay_Days"}))

# %%
avg_delay_by_category
# Out:
#       Category  Avg_Delay_Days
# 0  Accessories        6.107969
# 1     Clothing        6.153266
# 2  Electronics        6.215938
# 3         Food        6.188630
# 4    Furniture        6.268041
# 5         Misc        6.286885

# %%
top_5_products = (
    df.groupby("Product_Name", as_index=False)["Revenue"]
      .sum()
      .sort_values(by="Revenue", ascending=False)
      .head(5))

# %%
top_5_products
# Out:
#   Product_Name       Revenue
# 1   Headphones  1.024675e+07
# 3       Mobile  9.900159e+06
# 4       Tablet  9.768915e+06
# 0      Charger  9.168605e+06
# 2       Laptop  9.131004e+06

# %%
top_driver = df['Driver_Name'].value_counts().idxmax()
top_deliveries = df['Driver_Name'].value_counts().max()
print(top_driver, top_deliveries)
# Out:
# Mr. Rao 491

# %%
top_warehouse = df['Warehouse_Name'].value_counts().idxmax()
top_count = df['Warehouse_Name'].value_counts().max()
print(top_warehouse, top_count)
# Out:
# Central 594

# %%
avg_fuel_cost = df.groupby('Transport_Type')['Fuel_Cost'].mean()

# %%
avg_fuel_cost
# Out:
# Transport_Type
# Bike     5360.090904
# Cargo    5222.429422
# Truck    5262.713554
# Van      5258.537664
# Name: Fuel_Cost, dtype: float64

# %%
avg_fuel_cost  = (df.groupby("Transport_Type", as_index=False)["Fuel_Cost"]
      .mean()
      .rename(columns={"Fuel_Cost": "Avg_Fuel_Cost"}))

# %%
avg_fuel_cost
# Out:
#   Transport_Type  Avg_Fuel_Cost
# 0           Bike    5360.090904
# 1          Cargo    5222.429422
# 2          Truck    5262.713554
# 3            Van    5258.537664

# %%
total_revenue = (df.groupby(['Region', 'Country'])['Revenue']
      .sum()
      .reset_index())
print(total_revenue)
# Out:
#    Region  Country       Revenue
# 0    East    India  1.847146e+06
# 1    East       UK  3.359408e+06
# 2    East      USA  3.055286e+06
# 3    East  Unknown  1.758118e+06
# 4    East    india  1.623285e+06
# 5   North    India  1.312711e+06
# 6   North       UK  3.075219e+06
# 7   North      USA  2.810676e+06
# 8   North  Unknown  1.402736e+06
# 9   North    india  1.773959e+06
# 10  South    India  1.790103e+06
# 11  South       UK  3.603340e+06
# 12  South      USA  3.196614e+06
# 13  South  Unknown  1.793782e+06
# 14  South    india  1.443028e+06
# 15   West    India  1.602114e+06
# 16   West       UK  2.529098e+06
# 17   West      USA  2.772050e+06
# 18   West  Unknown  2.093260e+06
# 19   West    india  1.802493e+06

# %%
avg_delivery_duration = (
    df.groupby('Delivery_Mode')['Delivery_Duration']
      .mean()
      .reset_index())
print(avg_delivery_duration)
# Out:
#   Delivery_Mode           Delivery_Duration
# 0           Air 687 days 09:18:56.842105264
# 1          Rail 727 days 08:44:11.046025104
# 2          Road 701 days 02:11:45.882352944
# 3          Ship 737 days 15:02:16.708860760
# 4          road           704 days 12:41:36

# %%
df['Customer_Name'] = (
    df['Customer_Name']
      .astype(str)
      .str.strip()
      .str.title())
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\504338674.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Customer_Name'] = (

# %%
df['Delivery_Mode'] = (
    df['Delivery_Mode']
      .astype(str)
      .str.strip()
      .str.title())
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\2853567666.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Delivery_Mode'] = (

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name             Email  \
# 7        S734726   O77929       C3183  Michael Brown    amit@gmail.com
# 8        S728975   O40008       C3098     Jane Smith    amit@gmail.com
# 9        S427342   O36381       C5569       John Doe  john@example.com
# 15       S639574   O65339       C2260       John Doe             jane@
# 16       S694897   O55928       C7775  Michael Brown             jane@
# ...          ...      ...         ...            ...               ...
# 9977     S913811   O78710       C6685    Fatima Noor    amit@gmail.com
# 9980     S424262   O34605       C1678       John Doe    amit@gmail.com
# 9986     S663859   O33660       C6920     Jane Smith  john@example.com
# 9987     S996729   O86227       C3986  Michael Brown    amit@gmail.com
# 9995     S331063   O20146       C9393     Amit Kumar    amit@gmail.com
#
#              Phone       City  Country Region  Postal_Code  ... Return_Status  \
# ...

# %%
numeric_cols = df.select_dtypes(include='number').columns
df[numeric_cols] = df[numeric_cols].fillna(0)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\2121743050.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[numeric_cols] = df[numeric_cols].fillna(0)

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name             Email  \
# 7        S734726   O77929       C3183  Michael Brown    amit@gmail.com
# 8        S728975   O40008       C3098     Jane Smith    amit@gmail.com
# 9        S427342   O36381       C5569       John Doe  john@example.com
# 15       S639574   O65339       C2260       John Doe             jane@
# 16       S694897   O55928       C7775  Michael Brown             jane@
# ...          ...      ...         ...            ...               ...
# 9977     S913811   O78710       C6685    Fatima Noor    amit@gmail.com
# 9980     S424262   O34605       C1678       John Doe    amit@gmail.com
# 9986     S663859   O33660       C6920     Jane Smith  john@example.com
# 9987     S996729   O86227       C3986  Michael Brown    amit@gmail.com
# 9995     S331063   O20146       C9393     Amit Kumar    amit@gmail.com
#
#              Phone       City  Country Region  Postal_Code  ... Return_Status  \
# ...

# %%
mask = df["Shipment_Date"] > df["Delivery_Date"]
swapped_rows = df[mask]
df.loc[mask, ["Shipment_Date", "Delivery_Date"]] = (
    df.loc[mask, ["Delivery_Date", "Shipment_Date"]].values)

# %%
mask
# Out:
# 7       False
# 8       False
# 9       False
# 15      False
# 16      False
#         ...
# 9977    False
# 9980    False
# 9986    False
# 9987    False
# 9995    False
# Length: 2317, dtype: bool

# %%
conflicts = df.groupby(
    ["Order_ID", "Shipment_Date"]
).filter(lambda x:x["Status"].nunique() > 1)

# %%
conflicts
# Out:
# Empty DataFrame
# Columns: [Shipment_ID, Order_ID, Customer_ID, Customer_Name, Email, Phone, City, Country, Region, Postal_Code, Product_ID, Product_Name, Category, Weight_kg, Quantity, Unit_Price, Total_Price, Shipment_Date, Delivery_Date, Delay_Days, Status, Delivery_Mode, Vehicle_ID, Driver_Name, Transport_Type, Route_ID, Fuel_Cost, Distance_km, Delivery_Center, Warehouse_Name, Manager_Name, Order_Priority, Payment_Mode, Insurance, Return_Status, Remarks, Revenue, Delivery_Duration, Fuel_Efficiency, Profit, Delay_Flag, Urgency_Level, Payment_Mode_Encoded, Order_Priority_Encoded]
# Index: []
#
# [0 rows x 44 columns]

# %%
df["valid"] = ((df["Total_Price"] - df["Quantity"] * df["Unit_Price"]).abs() <= 0.01)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\1359609902.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["valid"] = ((df["Total_Price"] - df["Quantity"] * df["Unit_Price"]).abs() <= 0.01)

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name             Email  \
# 7        S734726   O77929       C3183  Michael Brown    amit@gmail.com
# 8        S728975   O40008       C3098     Jane Smith    amit@gmail.com
# 9        S427342   O36381       C5569       John Doe  john@example.com
# 15       S639574   O65339       C2260       John Doe             jane@
# 16       S694897   O55928       C7775  Michael Brown             jane@
# ...          ...      ...         ...            ...               ...
# 9977     S913811   O78710       C6685    Fatima Noor    amit@gmail.com
# 9980     S424262   O34605       C1678       John Doe    amit@gmail.com
# 9986     S663859   O33660       C6920     Jane Smith  john@example.com
# 9987     S996729   O86227       C3986  Michael Brown    amit@gmail.com
# 9995     S331063   O20146       C9393     Amit Kumar    amit@gmail.com
#
#              Phone       City  Country Region  Postal_Code  ...  \
# ...

# %%
import numpy as np
df=df.replace(r'^\s*$', np.nan, regex=True)

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name             Email  \
# 7        S734726   O77929       C3183  Michael Brown    amit@gmail.com
# 8        S728975   O40008       C3098     Jane Smith    amit@gmail.com
# 9        S427342   O36381       C5569       John Doe  john@example.com
# 15       S639574   O65339       C2260       John Doe             jane@
# 16       S694897   O55928       C7775  Michael Brown             jane@
# ...          ...      ...         ...            ...               ...
# 9977     S913811   O78710       C6685    Fatima Noor    amit@gmail.com
# 9980     S424262   O34605       C1678       John Doe    amit@gmail.com
# 9986     S663859   O33660       C6920     Jane Smith  john@example.com
# 9987     S996729   O86227       C3986  Michael Brown    amit@gmail.com
# 9995     S331063   O20146       C9393     Amit Kumar    amit@gmail.com
#
#              Phone       City  Country Region  Postal_Code  ...  \
# ...

# %%
df["Region"].fillna("Unknown",inplace=True)

# %%
df["Product_Name"].fillna("Unknown",inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\4170694032.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Product_Name"].fillna("Unknown",inplace=True)

# %%
df["Status"].fillna("Unknown",inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\4223991459.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Status"].fillna("Unknown",inplace=True)

# %%
df["Driver_Name"].fillna("Unknown",inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\2427605273.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Driver_Name"].fillna("Unknown",inplace=True)

# %%
df["Transport_Type"].fillna("Unknown",inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\1670296728.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Transport_Type"].fillna("Unknown",inplace=True)

# %%
df["Delivery_Center"].fillna("Unknown",inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\921766996.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Delivery_Center"].fillna("Unknown",inplace=True)

# %%
df["Warehouse_Name"].fillna("Unknown",inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\3353404119.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Warehouse_Name"].fillna("Unknown",inplace=True)

# %%
df["Manager_Name"].fillna("Unknown",inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\1289051196.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Manager_Name"].fillna("Unknown",inplace=True)

# %%
df["Order_Priority"].fillna("Unknown",inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\1479368997.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Order_Priority"].fillna("Unknown",inplace=True)

# %%
df["Payment_Mode"].fillna("Unknown",inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\384303531.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Payment_Mode"].fillna("Unknown",inplace=True)

# %%
df["Insurance"].fillna("Unknown",inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\1367601635.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Insurance"].fillna("Unknown",inplace=True)

# %%
df["Return_Status"].fillna("Unknown",inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\4181791310.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Return_Status"].fillna("Unknown",inplace=True)

# %%
df["Urgency_Level"].fillna("Unknown",inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15616\491449230.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Urgency_Level"].fillna("Unknown",inplace=True)

# %%
df
# Out:
#      Shipment_ID Order_ID Customer_ID  Customer_Name             Email  \
# 7        S734726   O77929       C3183  Michael Brown    amit@gmail.com
# 8        S728975   O40008       C3098     Jane Smith    amit@gmail.com
# 9        S427342   O36381       C5569       John Doe  john@example.com
# 15       S639574   O65339       C2260       John Doe             jane@
# 16       S694897   O55928       C7775  Michael Brown             jane@
# ...          ...      ...         ...            ...               ...
# 9977     S913811   O78710       C6685    Fatima Noor    amit@gmail.com
# 9980     S424262   O34605       C1678       John Doe    amit@gmail.com
# 9986     S663859   O33660       C6920     Jane Smith  john@example.com
# 9987     S996729   O86227       C3986  Michael Brown    amit@gmail.com
# 9995     S331063   O20146       C9393     Amit Kumar    amit@gmail.com
#
#              Phone       City  Country   Region  Postal_Code  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# Shipment_ID               0
# Order_ID                  0
# Customer_ID               0
# Customer_Name             0
# Email                     0
# Phone                     0
# City                      0
# Country                   0
# Region                    0
# Postal_Code               0
# Product_ID                0
# Product_Name              0
# Category                  0
# Weight_kg                 0
# Quantity                  0
# Unit_Price                0
# Total_Price               0
# Shipment_Date             0
# Delivery_Date             0
# Delay_Days                0
# Status                    0
# Delivery_Mode             0
# Vehicle_ID                0
# Driver_Name               0
# Transport_Type            0
# Route_ID                  0
# Fuel_Cost                 0
# Distance_km               0
# Delivery_Center           0
# Warehouse_Name            0
# Manager_Name              0
# Order_Priority            0
# Payment_Mode              0
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2317 entries, 7 to 9995
# Data columns (total 45 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Shipment_ID             2317 non-null   object
#  1   Order_ID                2317 non-null   object
#  2   Customer_ID             2317 non-null   object
#  3   Customer_Name           2317 non-null   object
#  4   Email                   2317 non-null   object
#  5   Phone                   2317 non-null   int64
#  6   City                    2317 non-null   object
#  7   Country                 2317 non-null   object
#  8   Region                  2317 non-null   object
#  9   Postal_Code             2317 non-null   float64
#  10  Product_ID              2317 non-null   object
#  11  Product_Name            2317 non-null   object
#  12  Category                2317 non-null   object
#  13  Weight_kg               2317 non-null   float64
# ...

# %%
df.to_csv('logistics_dataset_cleaned.csv', index=False)
